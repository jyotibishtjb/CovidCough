# %%
from getpass import getpass
token = getpass('Enter your GitHub PAT (Personal Access Token): ')
# Out:
# Enter your GitHub PAT (Personal Access Token): ··········

# %%
# !git clone https://github.com/jyotibishtjb/CovidCough.git
# %cd CovidCough
# Out:
# Cloning into 'CovidCough'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/CovidCough

# %%
# !cp "/content/CovidCough detection.ipynb" .

# %%
# !git config --global user.email "jyotikusham@gmail.com"
# !git config --global user.name "JBisht"

# !git add .
# !git commit -m "Upload files"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push https://jyotibishtjb:$token@github.com/jyotibishtjb/covidcough.git
# Out:
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/jyotibishtjb/covidcough.git/'

# %%
from google.colab import files

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer as si
# %matplotlib inline

# %%
db= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/metadata_compiled.csv')
db.head()
# Out:
#    Unnamed: 0                                  uuid  \
# 0           0  00014dcc-0f06-4c27-8c7b-737b18a2cf4c
# 1           1  00039425-7f3a-42aa-ac13-834aaa2b6b92
# 2           2  0007c6f1-5441-40e6-9aaf-a761d8f2da3b
# 3           3  00098cdb-4da1-4aa7-825a-4f1b9abc214b
# 4           4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a
#
#                            datetime  cough_detected  latitude  longitude  \
# 0  2020-11-25T18:58:50.488301+00:00          0.0155      48.9        2.4
# 1  2020-04-13T21:30:59.801831+00:00          0.9609      31.3       34.8
# 2  2020-10-18T15:38:38.205870+00:00          0.1643       NaN        NaN
# 3  2021-01-22T22:08:06.742577+00:00          0.1133      47.4        9.4
# 4  2020-04-12T04:02:18.159383+00:00          0.9301      40.0      -75.1
#
#     age  gender respiratory_condition fever_muscle_pain  ... quality_4  \
# 0   NaN     NaN                   NaN               NaN  ...       NaN
# ...

# %%
db.shape
# Out:
# (34434, 52)

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34434 entries, 0 to 34433
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             34434 non-null  int64
#  1   uuid                   34434 non-null  object
#  2   datetime               34434 non-null  object
#  3   cough_detected         34434 non-null  float64
#  4   latitude               19431 non-null  float64
#  5   longitude              19431 non-null  float64
#  6   age                    19396 non-null  float64
#  7   gender                 20664 non-null  object
#  8   respiratory_condition  20664 non-null  object
#  9   fever_muscle_pain      20664 non-null  object
#  10  status                 20664 non-null  object
#  11  status_SSL             8331 non-null   object
#  12  quality_1              820 non-null    object
#  13  cough_type_1           820 non-null    object
# ...

# %%
db.isnull().sum()
# Out:
# Unnamed: 0                   0
# uuid                         0
# datetime                     0
# cough_detected               0
# latitude                 15003
# longitude                15003
# age                      15038
# gender                   13770
# respiratory_condition    13770
# fever_muscle_pain        13770
# status                   13770
# status_SSL               26103
# quality_1                33614
# cough_type_1             33614
# dyspnea_1                33614
# wheezing_1               33614
# stridor_1                33614
# choking_1                33614
# congestion_1             33614
# nothing_1                33614
# diagnosis_1              33614
# severity_1               33614
# quality_2                33614
# cough_type_2             33615
# dyspnea_2                33614
# wheezing_2               33614
# stridor_2                33614
# choking_2                33614
# congestion_2             33614
# nothing_2                33614
# ...

# %%
db.describe()
# Out:
#          Unnamed: 0  cough_detected     latitude     longitude           age
# count  34434.000000    34434.000000  19431.00000  19431.000000  19396.000000
# mean   17216.500000        0.641199     33.30175      7.632628     36.758749
# std     9940.383921        0.383535     21.51791     53.968134     14.833325
# min        0.000000        0.000000    -54.80000   -158.100000      1.000000
# 25%     8608.250000        0.205150     33.70000     -3.800000     25.000000
# 50%    17216.500000        0.850450     41.00000      6.600000     35.000000
# 75%    25824.750000        0.977300     46.30000     32.500000     46.000000
# max    34433.000000        0.999400     65.10000    175.700000    102.000000

# %%
threshold = len(db) * 0.5
db.dropna(thresh= threshold, axis=1, inplace= True)

# %%
db.shape
# Out:
# (34434, 11)

# %%
db.head()
# Out:
#    Unnamed: 0                                  uuid  \
# 0           0  00014dcc-0f06-4c27-8c7b-737b18a2cf4c
# 1           1  00039425-7f3a-42aa-ac13-834aaa2b6b92
# 2           2  0007c6f1-5441-40e6-9aaf-a761d8f2da3b
# 3           3  00098cdb-4da1-4aa7-825a-4f1b9abc214b
# 4           4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a
#
#                            datetime  cough_detected  latitude  longitude  \
# 0  2020-11-25T18:58:50.488301+00:00          0.0155      48.9        2.4
# 1  2020-04-13T21:30:59.801831+00:00          0.9609      31.3       34.8
# 2  2020-10-18T15:38:38.205870+00:00          0.1643       NaN        NaN
# 3  2021-01-22T22:08:06.742577+00:00          0.1133      47.4        9.4
# 4  2020-04-12T04:02:18.159383+00:00          0.9301      40.0      -75.1
#
#     age  gender respiratory_condition fever_muscle_pain   status
# 0   NaN     NaN                   NaN               NaN      NaN
# 1  15.0    male                 False             False  healthy
# ...

# %%
db.tail()
# Out:
#        Unnamed: 0                                  uuid  \
# 34429       34429  fff3ff61-2387-4139-938b-539db01e6be5
# 34430       34430  fff474bf-39a4-4a61-8348-6b992fb5e439
# 34431       34431  fffaa9f8-4db0-46c5-90fb-93b7b014b55d
# 34432       34432  fffce9f0-a5e8-4bee-b13b-c671aac4a61c
# 34433       34433  fffd1834-6cf2-4782-bb30-04c31b46a1fe
#
#                                datetime  cough_detected  latitude  longitude  \
# 34429  2020-06-28T21:28:21.530881+00:00          0.5257      51.6       -0.2
# 34430  2020-04-10T05:10:36.787070+00:00          0.1945     -39.0      -68.1
# 34431  2020-04-13T18:58:26.954663+00:00          0.0243      41.0       28.8
# 34432  2020-04-14T13:02:33.307684+00:00          0.9754      41.0       28.7
# 34433  2021-07-21T13:16:19.493451+00:00          0.9754       NaN        NaN
#
#         age  gender respiratory_condition fever_muscle_pain       status
# 34429  35.0  female                 False             False  symptomatic
# ...

# %% [markdown]
# # Handle missing values

# %%
db["age"] = db["age"].fillna(db["age"].median())
